# %% [markdown]
# # Notebook 05 – PPO Agent Training (Revised)
# ## Multimodal FinRL Trading System for EGX
#
# This notebook trains a PPO agent using the multimodal dataset.
# The implementation strictly follows the FinRL API to avoid runtime errors.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -q finrl stable-baselines3 gymnasium pandas numpy

# %%
import os
import pandas as pd
import numpy as np

# !pip install alpaca-trade-api
# !pip install exchange-calendars

from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from stable_baselines3 import PPO
# Out:
# Requirement already satisfied: alpaca-trade-api in /usr/local/lib/python3.12/dist-packages (3.2.0)
# Requirement already satisfied: pandas>=0.18.1 in /usr/local/lib/python3.12/dist-packages (from alpaca-trade-api) (2.2.2)
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.12/dist-packages (from alpaca-trade-api) (2.0.2)
# Requirement already satisfied: requests<3,>2 in /usr/local/lib/python3.12/dist-packages (from alpaca-trade-api) (2.32.4)
# Requirement already satisfied: urllib3<2,>1.24 in /usr/local/lib/python3.12/dist-packages (from alpaca-trade-api) (1.26.20)
# Requirement already satisfied: websocket-client<2,>=0.56.0 in /usr/local/lib/python3.12/dist-packages (from alpaca-trade-api) (1.9.0)
# Requirement already satisfied: websockets<11,>=9.0 in /usr/local/lib/python3.12/dist-packages (from alpaca-trade-api) (10.4)
# Requirement already satisfied: msgpack==1.0.3 in /usr/local/lib/python3.12/dist-packages (from alpaca-trade-api) (1.0.3)
# Requirement already satisfied: aiohttp<4,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from alpaca-trade-api) (3.13.3)
# Requirement already satisfied: PyYAML==6.0.1 in /usr/local/lib/python3.12/dist-packages (from alpaca-trade-api) (6.0.1)
# Requirement already satisfied: deprecation==2.1.0 in /usr/local/lib/python3.12/dist-packages (from alpaca-trade-api) (2.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from deprecation==2.1.0->alpaca-trade-api) (25.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api) (1.22.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.18.1->alpaca-trade-api) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.18.1->alpaca-trade-api) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.18.1->alpaca-trade-api) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>2->alpaca-trade-api) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>2->alpaca-trade-api) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>2->alpaca-trade-api) (2026.1.4)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from aiosignal>=1.4.0->aiohttp<4,>=3.8.3->alpaca-trade-api) (4.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=0.18.1->alpaca-trade-api) (1.17.0)
# Requirement already satisfied: exchange-calendars in /usr/local/lib/python3.12/dist-packages (4.12)
# Requirement already satisfied: numpy>=1.26.4 in /usr/local/lib/python3.12/dist-packages (from exchange-calendars) (2.0.2)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from exchange-calendars) (2.2.2)
# Requirement already satisfied: pyluach>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from exchange-calendars) (2.3.0)
# Requirement already satisfied: toolz>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from exchange-calendars) (1.1.0)
# Requirement already satisfied: tzdata>=2025.2 in /usr/local/lib/python3.12/dist-packages (from exchange-calendars) (2025.3)
# Requirement already satisfied: korean_lunar_calendar>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from exchange-calendars) (0.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->exchange-calendars) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->exchange-calendars) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->exchange-calendars) (1.17.0)

# %%
BASE_DIR = '/content/drive/MyDrive/finrl-egx-multimodal'
DATA_PATH = os.path.join(BASE_DIR, 'data', 'multimodal_finrl_data.csv')
RESULTS_DIR = os.path.join(BASE_DIR, 'results')
os.makedirs(RESULTS_DIR, exist_ok=True)

# %%
df = pd.read_csv(DATA_PATH)
df['Date'] = pd.to_datetime(df['Date'])
df.rename(columns={'Close': 'close', 'Date': 'date', 'Adj Close': 'adjcp'}, inplace=True)
df['close'] = pd.to_numeric(df['close'], errors='coerce') # Ensure 'close' column is numeric
df = df.sort_values(['date', 'tic']).reset_index(drop=True) # Ensure 'date' is a column and a default integer index
df.head()
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#         date      adjcp      close               High                 Low  \
# 0 2020-03-15   1.230391   1.900000  2.059999942779541   1.850000023841858
# 1 2020-03-15  28.729263  31.472473  34.14461898803711  31.447547912597656
# 2 2020-03-15   6.516446   7.810000  8.380000114440918   7.769999980926514
# 3 2020-03-16   1.133255   1.750000  1.899999976158142  1.7100000381469727
# 4 2020-03-16  26.804270  29.363672  31.25810432434082  28.341678619384766
#
#                  Open    Volume  daily_return        rsi     sma_20  \
# 0   2.180000066757202   2335434     -0.128440  13.470857   1.802846
# 1  34.937286376953125  17661326     -0.100841  15.340648  36.029904
# 2   8.630000114440918   2740164     -0.072446  23.456790   7.719194
# 3   1.899999976158142   2396915     -0.078947  12.021511   1.754926
# 4   31.47247314453125   5148437     -0.067005  12.860626  35.425101
#
#       sma_50  volatility  sentiment_news  sentiment_social   tic
# 0   2.059285    0.042764        0.000000         -0.314831  AMOC
# 1  37.541819    0.031654        0.000000         -0.145865  COMI
# 2   8.512932    0.033478        0.000000         -0.099560  SWDY
# 3   2.034807    0.044315        0.000000         -0.696901  AMOC
# 4  37.321560    0.033519        0.078292          0.078292  COMI
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
TECH_INDICATORS = [
    'rsi', 'sma_20', 'sma_50', 'volatility',
    'sentiment_news', 'sentiment_social'
]

# %%
train_df = df[df['date'] < '2024-01-01'] # Use 'date' column for slicing
test_df = df[df['date'] >= '2024-01-01'] # Use 'date' column for slicing
print(train_df.shape, test_df.shape)
# Out:
# (2772, 15) (1452, 15)

# %%
import numpy as np
import pandas as pd # Explicitly import pandas

class CustomStockTradingEnv(StockTradingEnv):
    def __init__(self, df, stock_dim, hmax, initial_amount, num_stock_shares, buy_cost_pct, sell_cost_pct, reward_scaling, state_space, action_space, tech_indicator_list, turbulence_threshold=0, risk_indicator_col='vix', make_plots=False, print_verbosity=10, day=0, initial=True, previous_state=[], model_name='', mode='train', iteration=''):
        # Store unique sorted dates from the DataFrame BEFORE calling super().__init__
        self._trading_days = sorted(df['date'].unique())
        self.max_day = len(self._trading_days) - 1

        # Initialize balance and initial_cash BEFORE super().__init__
        self.balance = float(initial_amount) # Ensure balance is float
        self.initial_cash = float(initial_amount)

        # Initialize turbulence_make_day as it's used in the custom step method
        self.turbulence_make_day = 1 # Default to 1, meaning turbulence is checked every day

        # Call super().__init__. It will call self._initiate_state() which we have overridden.
        super().__init__(df, stock_dim, hmax, initial_amount, num_stock_shares, buy_cost_pct, sell_cost_pct, reward_scaling, state_space, action_space, tech_indicator_list, turbulence_threshold, risk_indicator_col, make_plots, print_verbosity, day, initial, previous_state, model_name, mode, iteration)

    def _get_data_for_current_day(self):
        # Helper method to get the correct DataFrame slice for the current day index
        if self.day > self.max_day: # This should be handled by terminal condition but as a safeguard
            return pd.DataFrame() # Return empty DataFrame if past valid days
        current_date = self._trading_days[self.day]
        data_for_day = self.df[self.df['date'] == current_date]
        if data_for_day.empty:
            raise ValueError(f"No data found for date: {current_date} at day index: {self.day}. Check your data or day indexing logic.")
        return data_for_day

    def _initiate_state(self):
        # Ensure self.data is always a DataFrame for the current day (self.day=0 initially)
        self.data = self._get_data_for_current_day()

        state = (
            [self.balance]
            + self.data.close.values.tolist() # current stock prices
            + self.num_stock_shares # current stock holdings
        )
        for indicator in self.tech_indicator_list:
            state += self.data[indicator].values.tolist()

        return state

    def _update_state(self):
        # Ensure self.data is always a DataFrame for the current day
        # This method is called after day increment in step, so self.data should reflect the new day.
        self.data = self._get_data_for_current_day()

        state = (
            [self.balance]
            + self.data.close.values.tolist()
            + self.num_stock_shares
        )
        for indicator in self.tech_indicator_list:
            state += self.data[indicator].values.tolist()
        return state

    def reset(self, seed=None, options=None):
        # Completely override reset to ensure proper initialization
        if seed is not None:
            # This is typically handled by the gymnasium wrapper
            pass

        self.day = 0
        self.data = self._get_data_for_current_day() # Ensure self.data is correct DataFrame for day 0

        self.initial = True
        self.num_stock_shares = [0] * self.stock_dim
        self.balance = self.initial_cash # Reset balance to initial
        self.cost = 0
        self.transactions = []
        self.rewards = []
        initial_asset_value = self.balance + sum(np.array(self.num_stock_shares) * np.array(self.data.close.values))
        self.asset_memory = [initial_asset_value]
        self.roi_memory = [0]
        self.state = self._initiate_state() # Calls our overridden _initiate_state

        self.account_information = {
            "cash": self.balance,
            "asset_value": sum(np.array(self.num_stock_shares) * np.array(self.data.close.values)),
            "number_of_stocks": sum(self.num_stock_shares),
            "total_assets": initial_asset_value
        }

        # Return state and info dictionary as per gymnasium API
        return self.state, self.account_information

    # Override the step method to control data fetching and turbulence calculation
    def step(self, actions):
        # print("CustomStockTradingEnv step called") # Debug statement
        self.terminal = self.day >= self.max_day

        if self.terminal:
            # Episode termination logic, return gymnasium-compatible format
            df_total_value = pd.DataFrame(self.asset_memory)
            tot_reward = self.asset_memory[-1] - self.asset_memory[0]
            df_total_value.columns = ["account_value"]
            df_total_value.set_index(df_total_value.columns[0], inplace=True)
            df_total_value.index.name = None
            if self.make_plots:
                self.plot(df_total_value)
            # Reward and state should be from the last valid step
            return self.state, self.rewards[-1] if self.rewards else 0.0, True, False, {"e": self.episode}

        else:
            # Get current day's data before processing actions
            self.data = self._get_data_for_current_day() # Ensure self.data is DataFrame for action processing

            begin_total_asset = self.balance + sum(self.num_stock_shares * self.data.close.values)

            # Process actions (actions here are expected to be from the agent, typically scaled by hmax)
            actions = np.array(actions) # Ensure actions are numpy array

            # Convert actions to desired share changes (FinRL's default assumes actions are normalized [-1, 1])
            # If actions are already shares, remove scaling by hmax
            # The problem context did not specify action space scaling, so I will assume actions are normalized and need hmax scaling.
            scaled_actions = actions * self.hmax # Scale actions by hmax
            scaled_actions = scaled_actions.astype(int) # Convert to integer shares

            argsort_actions = np.argsort(scaled_actions)
            sell_index = argsort_actions[:np.where(scaled_actions < 0)[0].shape[0]]
            buy_index = argsort_actions[::-1][:np.where(scaled_actions > 0)[0].shape[0]]

            # Execute sell orders
            for index in sell_index:
                if self.num_stock_shares[index] > 0:
                    sell_num_shares = min(abs(scaled_actions[index]), self.num_stock_shares[index])
                    self.balance += (
                        self.data.close.values[index] * sell_num_shares * (1 - self.sell_cost_pct)
                    )
                    self.num_stock_shares[index] -= sell_num_shares
                    self.cost += (
                        self.data.close.values[index] * sell_num_shares * self.sell_cost_pct
                    )
                    self.transactions.append(
                        (self.day, self.data.tic.values[index], "sell", self.data.close.values[index], sell_num_shares)
                    )

            # Execute buy orders
            for index in buy_index:
                # Ensure enough balance before buying
                price_with_cost = self.data.close.values[index] * (1 + self.buy_cost_pct)
                buy_num_shares = min(abs(scaled_actions[index]), int(self.balance // price_with_cost))
                if buy_num_shares > 0:
                    self.balance -= price_with_cost * buy_num_shares
                    self.num_stock_shares[index] += buy_num_shares
                    self.cost += (
                        self.data.close.values[index] * buy_num_shares * self.buy_cost_pct
                    )
                    self.transactions.append(
                        (self.day, self.data.tic.values[index], "buy", self.data.close.values[index], buy_num_shares)
                    )

            # Increment day to move to the next trading day
            self.day += 1

            # After incrementing day, get data for the new current day to update asset values and state
            if self.day <= self.max_day:
                self.data = self._get_data_for_current_day() # This updates self.data for the new day
            else:
                # If we just hit terminal state, self.data should still be the last day's data for calculations
                pass

            end_total_asset = self.balance + sum(np.array(self.num_stock_shares) * np.array(self.data.close.values))

            self.reward = end_total_asset - begin_total_asset
            self.rewards.append(self.reward)

            self.asset_memory.append(end_total_asset)
            self.roi_memory.append(
                ((end_total_asset - self.asset_memory[0]) / self.asset_memory[0]) * 100
            )

            # Recalculate state for the new day (using _update_state which ensures self.data is correct)
            self.state = self._update_state()

            # Turbulence calculation for the NEW day
            if self.turbulence_threshold is not None:
                if self.day % self.turbulence_make_day == 0 and self.day <= self.max_day:
                    # self.data is already a DataFrame for the current (new) day
                    # self.data[self.risk_indicator_col] will be a Series, .values[0] will be a float
                    # The turbulence value needs to be a float, not a DataFrame or Series
                    turbulence_value = self.data[self.risk_indicator_col].values
                    if len(turbulence_value) > 0:
                        self.turbulence = float(turbulence_value[0])
                    else:
                        self.turbulence = 0.0 # Default if no turbulence data for current day
                else:
                    self.turbulence = 0.0 # If not a turbulence day or past max day
            else:
                self.turbulence = 0.0

            self.terminal = self.day >= self.max_day # Update terminal status again

            self.info = {
                "day": self.day,
                "asset_memory": self.asset_memory[-1],
                "cash": self.balance,
                "num_stock_shares": self.num_stock_shares,
                "turbulence": self.turbulence,
                "current_date": self._trading_days[self.day] if self.day <= self.max_day else "Terminal"
            }

            return self.state, self.reward, self.terminal, False, self.info

# %%
stock_dim = len(train_df.tic.unique())
state_space = 1 + 2 * stock_dim + len(TECH_INDICATORS) * stock_dim
action_space = stock_dim

env_train = CustomStockTradingEnv(
    df=train_df,
    stock_dim=stock_dim,
    hmax=100,
    initial_amount=1_000_000,
    num_stock_shares=[0] * stock_dim,
    buy_cost_pct=0.001,
    sell_cost_pct=0.001,
    reward_scaling=1e-4,
    state_space=state_space,
    action_space=action_space,
    tech_indicator_list=TECH_INDICATORS,
    day=0,
    risk_indicator_col='volatility' # Ensure risk_indicator_col is passed here as well
)

# %%
model = PPO(
    'MlpPolicy',
    env_train,
    learning_rate=3e-4,
    n_steps=2048,
    batch_size=64,
    gamma=0.99,
    verbose=1
)
print("PPO model re-initialized with CustomStockTradingEnv.")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# PPO model re-initialized with CustomStockTradingEnv.

# %%
model.learn(total_timesteps=100_000)
print("PPO agent training complete.")
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 923      |
# |    ep_rew_mean     | 1.39e+05 |
# | time/              |          |
# |    fps             | 173      |
# |    iterations      | 1        |
# |    time_elapsed    | 11       |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 923          |
# |    ep_rew_mean          | 9.62e+04     |
# | time/                   |              |
# |    fps                  | 166          |
# |    iterations           | 2            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0042424607 |
# |    clip_fraction        | 0.0271       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.85e+07     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00262     |
# |    std                  | 0.995        |
# |    value_loss           | 6.12e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 923          |
# |    ep_rew_mean          | 9.03e+04     |
# | time/                   |              |
# |    fps                  | 196          |
# |    iterations           | 3            |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0035308986 |
# |    clip_fraction        | 0.0279       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.24        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.23e+06     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00181     |
# |    std                  | 0.994        |
# |    value_loss           | 7.55e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 923         |
# |    ep_rew_mean          | 1.08e+05    |
# | time/                   |             |
# |    fps                  | 214         |
# |    iterations           | 4           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.006346659 |
# |    clip_fraction        | 0.087       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.21e+07    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00238    |
# |    std                  | 0.989       |
# |    value_loss           | 1.88e+07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 923          |
# |    ep_rew_mean          | 1.33e+05     |
# | time/                   |              |
# |    fps                  | 222          |
# |    iterations           | 5            |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0054267524 |
# |    clip_fraction        | 0.0437       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.22        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.21e+07     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00503     |
# |    std                  | 0.989        |
# |    value_loss           | 8.37e+07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 923         |
# |    ep_rew_mean          | 1.5e+05     |
# | time/                   |             |
# |    fps                  | 224         |
# |    iterations           | 6           |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.001948493 |
# |    clip_fraction        | 0.000439    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.22       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.17e+08    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00111    |
# |    std                  | 0.989       |
# |    value_loss           | 2.43e+08    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 923         |
# |    ep_rew_mean          | 1.39e+05    |
# | time/                   |             |
# |    fps                  | 231         |
# |    iterations           | 7           |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.009724931 |
# |    clip_fraction        | 0.0489      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.02e+07    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.000876   |
# |    std                  | 0.99        |
# |    value_loss           | 2.11e+08    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 923          |
# |    ep_rew_mean          | 1.31e+05     |
# | time/                   |              |
# |    fps                  | 237          |
# |    iterations           | 8            |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0066239606 |
# |    clip_fraction        | 0.147        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.21        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.08e+07     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | 0.00208      |
# |    std                  | 0.98         |
# |    value_loss           | 2.15e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 923          |
# |    ep_rew_mean          | 1.29e+05     |
# | time/                   |              |
# |    fps                  | 244          |
# |    iterations           | 9            |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0046624523 |
# |    clip_fraction        | 0.0448       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.19        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.43e+07     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00131     |
# |    std                  | 0.973        |
# |    value_loss           | 1.67e+07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 923         |
# |    ep_rew_mean          | 1.27e+05    |
# | time/                   |             |
# |    fps                  | 247         |
# |    iterations           | 10          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.005290253 |
# |    clip_fraction        | 0.0421      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.17       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.98e+07    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.000874   |
# |    std                  | 0.973       |
# |    value_loss           | 7.36e+07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 923         |
# |    ep_rew_mean          | 1.31e+05    |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 11          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.004123846 |
# |    clip_fraction        | 0.0155      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.17       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.33e+07    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00103    |
# |    std                  | 0.971       |
# |    value_loss           | 5.22e+07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 923          |
# |    ep_rew_mean          | 1.42e+05     |
# | time/                   |              |
# |    fps                  | 255          |
# |    iterations           | 12           |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0053242976 |
# |    clip_fraction        | 0.0356       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.17        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.29e+07     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00011     |
# |    std                  | 0.969        |
# |    value_loss           | 1.09e+08     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 923         |
# |    ep_rew_mean          | 1.5e+05     |
# | time/                   |             |
# |    fps                  | 259         |
# |    iterations           | 13          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008044166 |
# |    clip_fraction        | 0.0448      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.16       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.32e+07    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | 0.000225    |
# |    std                  | 0.968       |
# |    value_loss           | 2.48e+08    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 923          |
# |    ep_rew_mean          | 1.43e+05     |
# | time/                   |              |
# |    fps                  | 261          |
# |    iterations           | 14           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0009850538 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.16        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.77e+08     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000311    |
# |    std                  | 0.969        |
# |    value_loss           | 2.67e+08     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 923          |
# |    ep_rew_mean          | 1.43e+05     |
# | time/                   |              |
# |    fps                  | 264          |
# |    iterations           | 15           |
# |    time_elapsed         | 116          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0006764204 |
# |    clip_fraction        | 0.0701       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.17        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.35e+07     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | 0.0014       |
# |    std                  | 0.971        |
# |    value_loss           | 3.02e+07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 923         |
# |    ep_rew_mean          | 1.48e+05    |
# | time/                   |             |
# |    fps                  | 264         |
# |    iterations           | 16          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.005435857 |
# |    clip_fraction        | 0.0478      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.17       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.25e+07    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00177    |
# |    std                  | 0.973       |
# |    value_loss           | 8.34e+07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 923          |
# |    ep_rew_mean          | 1.43e+05     |
# | time/                   |              |
# |    fps                  | 267          |
# |    iterations           | 17           |
# |    time_elapsed         | 130          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0049355645 |
# |    clip_fraction        | 0.00967      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.17        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.11e+07     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00213     |
# |    std                  | 0.973        |
# |    value_loss           | 1.91e+08     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 923         |
# |    ep_rew_mean          | 1.45e+05    |
# | time/                   |             |
# |    fps                  | 267         |
# |    iterations           | 18          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.018162746 |
# |    clip_fraction        | 0.264       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.18       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.37e+06    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.00993     |
# |    std                  | 0.976       |
# |    value_loss           | 2.01e+07    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 923           |
# |    ep_rew_mean          | 1.63e+05      |
# | time/                   |               |
# |    fps                  | 269           |
# |    iterations           | 19            |
# |    time_elapsed         | 144           |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 0.00010159396 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.18         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.22e+08      |
# |    n_updates            | 180           |
# |    policy_gradient_loss | 8.67e-05      |
# |    std                  | 0.976         |
# |    value_loss           | 3.19e+08      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 923           |
# |    ep_rew_mean          | 1.7e+05       |
# | time/                   |               |
# |    fps                  | 270           |
# |    iterations           | 20            |
# |    time_elapsed         | 151           |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 0.00022052895 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.18         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.94e+08      |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -0.00026      |
# |    std                  | 0.976         |
# |    value_loss           | 6.07e+08      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 923           |
# |    ep_rew_mean          | 1.75e+05      |
# | time/                   |               |
# |    fps                  | 272           |
# |    iterations           | 21            |
# |    time_elapsed         | 157           |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 2.8660288e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.18         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.08e+08      |
# |    n_updates            | 200           |
# |    policy_gradient_loss | 2.15e-05      |
# |    std                  | 0.976         |
# |    value_loss           | 3.37e+08      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 923          |
# |    ep_rew_mean          | 1.77e+05     |
# | time/                   |              |
# |    fps                  | 273          |
# |    iterations           | 22           |
# |    time_elapsed         | 164          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0061159013 |
# |    clip_fraction        | 0.0836       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.18        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.46e+07     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | 0.00235      |
# |    std                  | 0.974        |
# |    value_loss           | 2.81e+08     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 923         |
# |    ep_rew_mean          | 1.76e+05    |
# | time/                   |             |
# |    fps                  | 275         |
# |    iterations           | 23          |
# |    time_elapsed         | 171         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.000427562 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.18       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.7e+07     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.000222   |
# |    std                  | 0.974       |
# |    value_loss           | 2.28e+08    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 923         |
# |    ep_rew_mean          | 1.76e+05    |
# | time/                   |             |
# |    fps                  | 275         |
# |    iterations           | 24          |
# |    time_elapsed         | 178         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.005596335 |
# |    clip_fraction        | 0.028       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.18       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.05e+07    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 9.89e-05    |
# |    std                  | 0.973       |
# |    value_loss           | 1.18e+08    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 923           |
# |    ep_rew_mean          | 1.78e+05      |
# | time/                   |               |
# |    fps                  | 277           |
# |    iterations           | 25            |
# |    time_elapsed         | 184           |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 0.00079056213 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.18         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.86e+07      |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -0.000488     |
# |    std                  | 0.974         |
# |    value_loss           | 1.04e+08      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 923         |
# |    ep_rew_mean          | 1.8e+05     |
# | time/                   |             |
# |    fps                  | 277         |
# |    iterations           | 26          |
# |    time_elapsed         | 191         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.003902624 |
# |    clip_fraction        | 0.00615     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.18       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.21e+07    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00123    |
# |    std                  | 0.973       |
# |    value_loss           | 1.73e+08    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 923         |
# |    ep_rew_mean          | 1.81e+05    |
# | time/                   |             |
# |    fps                  | 279         |
# |    iterations           | 27          |
# |    time_elapsed         | 198         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.004597819 |
# |    clip_fraction        | 0.0111      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.17       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.88e+07    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00206    |
# |    std                  | 0.971       |
# |    value_loss           | 1.76e+08    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 923           |
# |    ep_rew_mean          | 1.81e+05      |
# | time/                   |               |
# |    fps                  | 278           |
# |    iterations           | 28            |
# |    time_elapsed         | 206           |
# |    total_timesteps      | 57344         |
# | train/                  |               |
# |    approx_kl            | 0.00034266192 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.17         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.01e+07      |
# |    n_updates            | 270           |
# |    policy_gradient_loss | 0.000177      |
# |    std                  | 0.972         |
# |    value_loss           | 1.71e+08      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 923          |
# |    ep_rew_mean          | 1.84e+05     |
# | time/                   |              |
# |    fps                  | 279          |
# |    iterations           | 29           |
# |    time_elapsed         | 212          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0036442177 |
# |    clip_fraction        | 0.00337      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.17        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.09e+07     |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00207     |
# |    std                  | 0.971        |
# |    value_loss           | 1.06e+08     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 923          |
# |    ep_rew_mean          | 1.84e+05     |
# | time/                   |              |
# |    fps                  | 279          |
# |    iterations           | 30           |
# |    time_elapsed         | 219          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0043630116 |
# |    clip_fraction        | 0.00732      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.17        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.38e+07     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00068     |
# |    std                  | 0.971        |
# |    value_loss           | 2.43e+08     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 923          |
# |    ep_rew_mean          | 1.84e+05     |
# | time/                   |              |
# |    fps                  | 281          |
# |    iterations           | 31           |
# |    time_elapsed         | 225          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0055325106 |
# |    clip_fraction        | 0.0383       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.16        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.46e+07     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00476     |
# |    std                  | 0.968        |
# |    value_loss           | 9.83e+07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 923         |
# |    ep_rew_mean          | 1.9e+05     |
# | time/                   |             |
# |    fps                  | 281         |
# |    iterations           | 32          |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.004743467 |
# |    clip_fraction        | 0.00796     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.16       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.08e+07    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00217    |
# |    std                  | 0.965       |
# |    value_loss           | 1.18e+08    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 923        |
# |    ep_rew_mean          | 1.94e+05   |
# | time/                   |            |
# |    fps                  | 282        |
# |    iterations           | 33         |
# |    time_elapsed         | 239        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.00398079 |
# |    clip_fraction        | 0.0224     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.15      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.04e+08   |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.000749  |
# |    std                  | 0.965      |
# |    value_loss           | 4.31e+08   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 923          |
# |    ep_rew_mean          | 1.97e+05     |
# | time/                   |              |
# |    fps                  | 281          |
# |    iterations           | 34           |
# |    time_elapsed         | 246          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0058943126 |
# |    clip_fraction        | 0.0226       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.15        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.09e+08     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00295     |
# |    std                  | 0.965        |
# |    value_loss           | 3.74e+08     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 923          |
# |    ep_rew_mean          | 2e+05        |
# | time/                   |              |
# |    fps                  | 282          |
# |    iterations           | 35           |
# |    time_elapsed         | 253          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0034816642 |
# |    clip_fraction        | 0.00859      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.15        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.2e+07      |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00187     |
# |    std                  | 0.965        |
# |    value_loss           | 3e+08        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 923          |
# |    ep_rew_mean          | 2.01e+05     |
# | time/                   |              |
# |    fps                  | 282          |
# |    iterations           | 36           |
# |    time_elapsed         | 260          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0060762474 |
# |    clip_fraction        | 0.0248       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.15        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.32e+08     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00165     |
# |    std                  | 0.967        |
# |    value_loss           | 2.95e+08     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 923          |
# |    ep_rew_mean          | 2.01e+05     |
# | time/                   |              |
# |    fps                  | 283          |
# |    iterations           | 37           |
# |    time_elapsed         | 266          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0018301744 |
# |    clip_fraction        | 0.0125       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.15        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.51e+08     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | 0.000716     |
# |    std                  | 0.966        |
# |    value_loss           | 1.93e+08     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 923         |
# |    ep_rew_mean          | 2e+05       |
# | time/                   |             |
# |    fps                  | 283         |
# |    iterations           | 38          |
# |    time_elapsed         | 274         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.004859424 |
# |    clip_fraction        | 0.0178      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.15       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.91e+07    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00258    |
# |    std                  | 0.964       |
# |    value_loss           | 1.74e+08    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 923          |
# |    ep_rew_mean          | 1.98e+05     |
# | time/                   |              |
# |    fps                  | 284          |
# |    iterations           | 39           |
# |    time_elapsed         | 280          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0052235546 |
# |    clip_fraction        | 0.0256       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.15        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.45e+07     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00279     |
# |    std                  | 0.963        |
# |    value_loss           | 1.18e+08     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 923         |
# |    ep_rew_mean          | 1.97e+05    |
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 40          |
# |    time_elapsed         | 287         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.005742359 |
# |    clip_fraction        | 0.0897      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.14       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.39e+06    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00198    |
# |    std                  | 0.962       |
# |    value_loss           | 2.37e+07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 923         |
# |    ep_rew_mean          | 2e+05       |
# | time/                   |             |
# |    fps                  | 285         |
# |    iterations           | 41          |
# |    time_elapsed         | 294         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.003944762 |
# |    clip_fraction        | 0.00991     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.14       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.48e+07    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00156    |
# |    std                  | 0.96        |
# |    value_loss           | 9.02e+07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 923          |
# |    ep_rew_mean          | 2.03e+05     |
# | time/                   |              |
# |    fps                  | 285          |
# |    iterations           | 42           |
# |    time_elapsed         | 301          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0052484414 |
# |    clip_fraction        | 0.0148       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.14        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.9e+08      |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.0031      |
# |    std                  | 0.961        |
# |    value_loss           | 5.16e+08     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 923         |
# |    ep_rew_mean          | 2.09e+05    |
# | time/                   |             |
# |    fps                  | 286         |
# |    iterations           | 43          |
# |    time_elapsed         | 307         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.004212834 |
# |    clip_fraction        | 0.0188      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.14       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.56e+07    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00192    |
# |    std                  | 0.96        |
# |    value_loss           | 2.22e+08    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 923         |
# |    ep_rew_mean          | 2.23e+05    |
# | time/                   |             |
# |    fps                  | 286         |
# |    iterations           | 44          |
# |    time_elapsed         | 314         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.095086545 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.13       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.62e+08    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.013       |
# |    std                  | 0.959       |
# |    value_loss           | 6.81e+08    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 923           |
# |    ep_rew_mean          | 2.35e+05      |
# | time/                   |               |
# |    fps                  | 286           |
# |    iterations           | 45            |
# |    time_elapsed         | 321           |
# |    total_timesteps      | 92160         |
# | train/                  |               |
# |    approx_kl            | 0.00023008027 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.13         |
# |    explained_variance   | 2.26e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.01e+09      |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -0.000336     |
# |    std                  | 0.959         |
# |    value_loss           | 2.64e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 923           |
# |    ep_rew_mean          | 2.56e+05      |
# | time/                   |               |
# |    fps                  | 286           |
# |    iterations           | 46            |
# |    time_elapsed         | 328           |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 6.0675084e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.13         |
# |    explained_variance   | 2.38e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.38e+09      |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -5.23e-05     |
# |    std                  | 0.959         |
# |    value_loss           | 2.66e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 923           |
# |    ep_rew_mean          | 2.72e+05      |
# | time/                   |               |
# |    fps                  | 287           |
# |    iterations           | 47            |
# |    time_elapsed         | 335           |
# |    total_timesteps      | 96256         |
# | train/                  |               |
# |    approx_kl            | 4.4588494e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.13         |
# |    explained_variance   | 3.16e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.28e+09      |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -0.000125     |
# |    std                  | 0.959         |
# |    value_loss           | 2.91e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 923           |
# |    ep_rew_mean          | 2.85e+05      |
# | time/                   |               |
# |    fps                  | 287           |
# |    iterations           | 48            |
# |    time_elapsed         | 342           |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 0.00026985275 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.13         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.33e+08      |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -0.000764     |
# |    std                  | 0.959         |
# |    value_loss           | 2.37e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 923           |
# |    ep_rew_mean          | 3e+05         |
# | time/                   |               |
# |    fps                  | 287           |
# |    iterations           | 49            |
# |    time_elapsed         | 348           |
# |    total_timesteps      | 100352        |
# | train/                  |               |
# |    approx_kl            | 0.00026094826 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.13         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.27e+08      |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -0.000456     |
# |    std                  | 0.958         |
# |    value_loss           | 1.69e+09      |
# -------------------------------------------
# PPO agent training complete.

# %% [markdown]
# # Task
# The PPO agent has been trained. I'll proceed to save the trained model.

# %% [markdown]
# ## Save Trained Model
#
# ### Subtask:
# Save the trained PPO model to the designated RESULTS_DIR for future use.

# %% [markdown]
# **Reasoning**:
# The training of the PPO agent is complete, and now I need to save the trained model to the designated RESULTS_DIR using `model.save(MODEL_PATH)` as instructed. Afterward, I will print a confirmation message.

# %%
MODEL_PATH = os.path.join(RESULTS_DIR, 'ppo_multimodal_model')
model.save(MODEL_PATH)
print('Saved to', MODEL_PATH)
# Out:
# Saved to /content/drive/MyDrive/finrl-egx-multimodal/results/ppo_multimodal_model

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Confirm the successful training and saving of the PPO agent.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The PPO model was successfully saved to the path `/content/drive/MyDrive/finrl-egx-multimodal/results/ppo_multimodal_model`.
# *   A confirmation message indicated the successful completion of the save operation.
#
# ### Insights or Next Steps
#
# *   The trained PPO agent is now persistently stored and ready for subsequent evaluation or deployment phases.
